# %% [markdown]
# # CS5242

# %% [markdown]
# ## Load Data

# %%
from data import Data

train_data = Data(data_type='train')
test_data = Data(data_type='test')

print("Train data: x:"+ str(train_data.x.shape)+ ' y:'+str(train_data.y.shape))
print("Test data: x:"+ str(test_data.x.shape)+ ' y:'+str(test_data.y.shape))
# Out:
# Loading train data 18662/18662: 100%|█████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# Loading test data 6051/6051: 100%|████████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# Train data: x:(18662, 1000, 102) y:(18662, 1)
# Test data: x:(6051, 1000, 102) y:(6051, 1)

# %% [markdown]
# ## Model

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(256,return_sequences=True)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(1e-3),
              metrics=['accuracy'])

# %% [markdown]
# ## Save Checkpoint

# %%
import os
# Directory where the checkpoints will be saved
checkpoint_dir = './training_checkpoints_gru_256_temperal'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True)

# %%
history = model.fit(x=train_data.x, y=train_data.y, validation_split=0.1, epochs=20,
                    callbacks=[checkpoint_callback], verbose=2,shuffle=True)
# Out:
# Train on 16795 samples, validate on 1867 samples
# Epoch 1/20
# 16795/16795 - 53s - loss: 0.0126 - accuracy: 0.9843 - val_loss: 0.0427 - val_accuracy: 0.9519
# Epoch 2/20
# 16795/16795 - 58s - loss: 0.0126 - accuracy: 0.9843 - val_loss: 0.0416 - val_accuracy: 0.9552
# Epoch 3/20
# 16795/16795 - 56s - loss: 0.0120 - accuracy: 0.9850 - val_loss: 0.0430 - val_accuracy: 0.9518
# Epoch 4/20
# 16795/16795 - 57s - loss: 0.0122 - accuracy: 0.9847 - val_loss: 0.0458 - val_accuracy: 0.9491
# Epoch 5/20
# 16795/16795 - 57s - loss: 0.0125 - accuracy: 0.9843 - val_loss: 0.0431 - val_accuracy: 0.9525
# Epoch 6/20
# 16795/16795 - 56s - loss: 0.0127 - accuracy: 0.9845 - val_loss: 0.0414 - val_accuracy: 0.9560
# Epoch 7/20
# 16795/16795 - 57s - loss: 0.0124 - accuracy: 0.9848 - val_loss: 0.0440 - val_accuracy: 0.9522
# Epoch 8/20
# 16795/16795 - 57s - loss: 0.0116 - accuracy: 0.9857 - val_loss: 0.0411 - val_accuracy: 0.9556
# Epoch 9/20
# 16795/16795 - 57s - loss: 0.0120 - accuracy: 0.9848 - val_loss: 0.0433 - val_accuracy: 0.9557
# Epoch 10/20
# 16795/16795 - 58s - loss: 0.0127 - accuracy: 0.9842 - val_loss: 0.0412 - val_accuracy: 0.9554
# Epoch 11/20
# 16795/16795 - 57s - loss: 0.0133 - accuracy: 0.9834 - val_loss: 0.0408 - val_accuracy: 0.9537
# Epoch 12/20
# 16795/16795 - 58s - loss: 0.0133 - accuracy: 0.9835 - val_loss: 0.0385 - val_accuracy: 0.9579
# Epoch 13/20
# 16795/16795 - 59s - loss: 0.0118 - accuracy: 0.9851 - val_loss: 0.0384 - val_accuracy: 0.9580
# Epoch 14/20
# 16795/16795 - 57s - loss: 0.0115 - accuracy: 0.9857 - val_loss: 0.0392 - val_accuracy: 0.9577
# Epoch 15/20
# 16795/16795 - 57s - loss: 0.0112 - accuracy: 0.9859 - val_loss: 0.0416 - val_accuracy: 0.9563
# Epoch 16/20
# 16795/16795 - 57s - loss: 0.0112 - accuracy: 0.9859 - val_loss: 0.0400 - val_accuracy: 0.9549
# Epoch 17/20
# 16795/16795 - 57s - loss: 0.0110 - accuracy: 0.9864 - val_loss: 0.0421 - val_accuracy: 0.9542
# Epoch 18/20
# 16795/16795 - 57s - loss: 0.0108 - accuracy: 0.9865 - val_loss: 0.0449 - val_accuracy: 0.9538
# Epoch 19/20
# 16795/16795 - 58s - loss: 0.0120 - accuracy: 0.9855 - val_loss: 0.0494 - val_accuracy: 0.9462
# Epoch 20/20
# 16795/16795 - 59s - loss: 0.0140 - accuracy: 0.9830 - val_loss: 0.0415 - val_accuracy: 0.9520

# %% [markdown]
# ## Plot Training History

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection multiple                  552960
# _________________________________________________________________
# dense_6 (Dense)              multiple                  32832
# _________________________________________________________________
# dropout_3 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_7 (Dense)              multiple                  65
# =================================================================
# Total params: 585,857
# Trainable params: 585,857
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Restore Weights

# %%
checkpoint_dir = './training_checkpoints_gru_256_temperal'
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))

# %%
test_predict = model.predict(test_data.x)
print(test_predict.shape)
# Out:
# (6051, 1000, 1)

# %% [markdown]
# ## Save Prediction to CSV

# %%
import csv

output_file = 'result_gru_256_dropout_temperal.csv'
with open(output_file, 'wt', newline='', encoding='utf-8') as output_file:
    csv_writer = csv.writer(output_file)
    csv_writer.writerow(('Id', 'Predicted'))
    for id, predict in enumerate(test_predict):
        csv_writer.writerow((id, predict[0][0]))
