# %% [markdown]
# # CS5242

# %% [markdown]
# ## Load Data

# %%
from data import Data
import numpy as np

full_train = Data(data_type='train')

# idx = np.random.permutation(len(full_train.x))
# full_train_x,full_train_y = full_train.x[idx], full_train.y[idx]
full_train_x,full_train_y = full_train.x, full_train.y


del full_train

val_data_x, train_data_x = full_train_x[:full_train_x.shape[0]//5,:], full_train_x[full_train_x.shape[0]//5:,:]
val_data_y,train_data_y = full_train_y[:full_train_y.shape[0]//5,:], full_train_y[full_train_y.shape[0]//5:,:]

print("Train data: x:"+ str(train_data_x.shape)+ ' y:'+str(train_data_y.shape))
print("Validation data: x:"+ str(val_data_x.shape)+ ' y:'+str(val_data_y.shape))
# Out:
# Loading train data 18662/18662: 100%|█████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# Train data: x:(14930, 1000, 102) y:(14930, 1)
# Validation data: x:(3732, 1000, 102) y:(3732, 1)

# %% [markdown]
# ## Model

# %%
import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

model_name = 'boosting_lstm_256'

def create_model(show_summary = False):
    model = tf.keras.Sequential([
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256),input_shape=(1000,102)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1, activation='sigmoid')
])

    model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.Adam(1e-3),
              metrics=['accuracy',tf.keras.metrics.AUC()])
    
    if show_summary:
        model.summary()
    
    return model
    
num_of_bags = 3
epochs_per_bag = 50
start_from_bag = 3

# %% [markdown]
# ## Training with Boosting

# %%
import os
import matplotlib.pyplot as plt
import csv
import math
from data import Data

# %matplotlib inline
    
training_loss = np.ones(train_data_x.shape[0])

for bag in range(num_of_bags):
    # skip training
    if bag < start_from_bag:
        print("skiping bag "+str(bag))
        continue
    print("Training bag "+str(bag))

    # Put data into bags
    model = create_model(False)
    train_size = train_data_x.shape[0]//10*4
    if bag != 0 :
        # Check prediction for training data
        for validate_bag in range(bag):
            checkpoint_dir = './checkpoints/' + model_name+ '_bag'+ str(validate_bag)
            model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
            if validate_bag == 0:
                predictions = model.predict(train_data_x)
            else:
                predictions = np.concatenate((predictions,model.predict(train_data_x)),axis=1)
        print(predictions.shape)

        avg_predictions = np.mean(predictions, axis=1)
        print(avg_predictions.shape)
        
        # Select training data poorly predicted 
        training_loss = avg_predictions-np.reshape(train_data_y,(train_data_y.shape[0]))
        training_loss = np.absolute(training_loss)
        print(training_loss)
        
        # Save Predictions for test data
        test_data = Data(data_type='test')
        for validate_bag in range(bag):
            checkpoint_dir = './checkpoints/' + model_name+ '_bag'+ str(validate_bag)
            model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
            if validate_bag == 0:
                predictions = model.predict(test_data.x)
            else:
                predictions = np.concatenate((predictions,model.predict(test_data.x)),axis=1)
        print(predictions.shape)

        avg_predictions = np.mean(predictions, axis=1)
        print(avg_predictions.shape)
        
        output_file = 'result_' + model_name +'_boost'+ str(bag) +'.csv'
        with open(output_file, 'wt', newline='', encoding='utf-8') as output_file:
            csv_writer = csv.writer(output_file)
            csv_writer.writerow(('Id', 'Predicted'))
            for id, predict in enumerate(avg_predictions):
                csv_writer.writerow((id, predict))
        print('Saved to '+'result_' + model_name +'_boost'+ str(bag) +'.csv')
        # Free memory space for test data
        del test_data
        
        
    
    idx = (-training_loss).argsort()[:train_size]
    print(training_loss[idx])
    bag_x,bag_y = train_data_x[idx], train_data_y[idx]
        
    del model
        
    ## TODO define different models if possible
    model = create_model(bag==0)
    # Directory where the checkpoints will be saved
    checkpoint_dir = './checkpoints/' + model_name+ '_bag'+ str(bag)
    # Name of the checkpoint files
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

    checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_prefix,
        monitor='accuracy',
        save_best_only=True,
        save_weights_only=True)

    early_stopping_callback = tf.keras.callbacks.EarlyStopping(
        monitor='accuracy', 
        min_delta=0, 
        patience=10, 
        mode='auto', 
        restore_best_weights=True)
        
        
        
    history = model.fit(x=bag_x,y=bag_y, validation_data=(val_data_x,val_data_y), epochs=epochs_per_bag,batch_size=32,
                    callbacks=[checkpoint_callback,early_stopping_callback], verbose=2,shuffle=True)
    
    print()
    
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()
    
    del model,history,bag_x,bag_y
# Out:
# Training bag 0
# [1. 1. 1. ... 1. 1. 1.]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 512)               735232
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 768,129
# Trainable params: 768,129
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5972 samples, validate on 3732 samples
# Epoch 1/50
# 5972/5972 - 27s - loss: 0.3584 - accuracy: 0.8356 - auc_1: 0.9196 - val_loss: 0.2749 - val_accuracy: 0.8893 - val_auc_1: 0.9546
# Epoch 2/50
# 5972/5972 - 24s - loss: 0.2659 - accuracy: 0.8851 - auc_1: 0.9567 - val_loss: 0.2459 - val_accuracy: 0.8939 - val_auc_1: 0.9620
# Epoch 3/50
# 5972/5972 - 24s - loss: 0.2408 - accuracy: 0.8945 - auc_1: 0.9645 - val_loss: 0.2249 - val_accuracy: 0.9108 - val_auc_1: 0.9675
# Epoch 4/50
# 5972/5972 - 24s - loss: 0.2014 - accuracy: 0.9148 - auc_1: 0.9752 - val_loss: 0.2241 - val_accuracy: 0.9073 - val_auc_1: 0.9687
# Epoch 5/50
# 5972/5972 - 24s - loss: 0.1812 - accuracy: 0.9248 - auc_1: 0.9798 - val_loss: 0.2326 - val_accuracy: 0.9073 - val_auc_1: 0.9708
# Epoch 6/50
# 5972/5972 - 24s - loss: 0.1710 - accuracy: 0.9270 - auc_1: 0.9820 - val_loss: 0.2262 - val_accuracy: 0.9156 - val_auc_1: 0.9701
# Epoch 7/50
# 5972/5972 - 24s - loss: 0.1606 - accuracy: 0.9357 - auc_1: 0.9840 - val_loss: 0.2146 - val_accuracy: 0.9102 - val_auc_1: 0.9715
# Epoch 8/50
# 5972/5972 - 24s - loss: 0.1420 - accuracy: 0.9434 - auc_1: 0.9871 - val_loss: 0.2336 - val_accuracy: 0.9156 - val_auc_1: 0.9720
# Epoch 9/50
# 5972/5972 - 24s - loss: 0.1461 - accuracy: 0.9449 - auc_1: 0.9866 - val_loss: 0.2411 - val_accuracy: 0.9089 - val_auc_1: 0.9677
# Epoch 10/50
# 5972/5972 - 24s - loss: 0.1216 - accuracy: 0.9536 - auc_1: 0.9899 - val_loss: 0.2210 - val_accuracy: 0.9252 - val_auc_1: 0.9735
# Epoch 11/50
# 5972/5972 - 24s - loss: 0.1116 - accuracy: 0.9588 - auc_1: 0.9917 - val_loss: 0.2333 - val_accuracy: 0.9218 - val_auc_1: 0.9713
# Epoch 12/50
# 5972/5972 - 24s - loss: 0.1020 - accuracy: 0.9628 - auc_1: 0.9924 - val_loss: 0.2249 - val_accuracy: 0.9207 - val_auc_1: 0.9724
# Epoch 13/50
# 5972/5972 - 24s - loss: 0.0976 - accuracy: 0.9638 - auc_1: 0.9931 - val_loss: 0.2320 - val_accuracy: 0.9252 - val_auc_1: 0.9731
# Epoch 14/50
# 5972/5972 - 24s - loss: 0.0853 - accuracy: 0.9694 - auc_1: 0.9944 - val_loss: 0.2522 - val_accuracy: 0.9306 - val_auc_1: 0.9729
# Epoch 15/50
# 5972/5972 - 24s - loss: 0.0811 - accuracy: 0.9709 - auc_1: 0.9950 - val_loss: 0.2728 - val_accuracy: 0.9226 - val_auc_1: 0.9661
# Epoch 16/50
# 5972/5972 - 25s - loss: 0.0793 - accuracy: 0.9727 - auc_1: 0.9949 - val_loss: 0.2687 - val_accuracy: 0.9118 - val_auc_1: 0.9655
# Epoch 17/50
# 5972/5972 - 24s - loss: 0.0776 - accuracy: 0.9709 - auc_1: 0.9951 - val_loss: 0.2612 - val_accuracy: 0.9247 - val_auc_1: 0.9699
# Epoch 18/50
# 5972/5972 - 24s - loss: 0.0679 - accuracy: 0.9759 - auc_1: 0.9960 - val_loss: 0.2905 - val_accuracy: 0.9277 - val_auc_1: 0.9671
# Epoch 19/50
# 5972/5972 - 24s - loss: 0.0703 - accuracy: 0.9745 - auc_1: 0.9960 - val_loss: 0.2818 - val_accuracy: 0.9301 - val_auc_1: 0.9693
# Epoch 20/50
# 5972/5972 - 24s - loss: 0.0661 - accuracy: 0.9745 - auc_1: 0.9964 - val_loss: 0.2709 - val_accuracy: 0.9263 - val_auc_1: 0.9700
# Epoch 21/50
# 5972/5972 - 24s - loss: 0.0688 - accuracy: 0.9745 - auc_1: 0.9963 - val_loss: 0.2760 - val_accuracy: 0.9268 - val_auc_1: 0.9676
# Epoch 22/50
# 5972/5972 - 24s - loss: 0.0592 - accuracy: 0.9789 - auc_1: 0.9969 - val_loss: 0.3353 - val_accuracy: 0.9105 - val_auc_1: 0.9579
# Epoch 23/50
# 5972/5972 - 24s - loss: 0.0636 - accuracy: 0.9769 - auc_1: 0.9963 - val_loss: 0.3201 - val_accuracy: 0.9311 - val_auc_1: 0.9654
# Epoch 24/50
# 5972/5972 - 24s - loss: 0.0566 - accuracy: 0.9807 - auc_1: 0.9972 - val_loss: 0.3133 - val_accuracy: 0.9306 - val_auc_1: 0.9678
# Epoch 25/50
# 5972/5972 - 24s - loss: 0.0518 - accuracy: 0.9817 - auc_1: 0.9977 - val_loss: 0.3082 - val_accuracy: 0.9327 - val_auc_1: 0.9673
# Epoch 26/50
# 5972/5972 - 24s - loss: 0.0497 - accuracy: 0.9831 - auc_1: 0.9974 - val_loss: 0.3356 - val_accuracy: 0.9319 - val_auc_1: 0.9649
# Epoch 27/50
# 5972/5972 - 25s - loss: 0.0601 - accuracy: 0.9796 - auc_1: 0.9968 - val_loss: 0.3282 - val_accuracy: 0.9271 - val_auc_1: 0.9630
# Epoch 28/50
# 5972/5972 - 25s - loss: 0.0672 - accuracy: 0.9766 - auc_1: 0.9964 - val_loss: 0.2926 - val_accuracy: 0.9282 - val_auc_1: 0.9673
# Epoch 29/50
# 5972/5972 - 25s - loss: 0.0719 - accuracy: 0.9737 - auc_1: 0.9956 - val_loss: 0.2831 - val_accuracy: 0.9258 - val_auc_1: 0.9666
# Epoch 30/50
# 5972/5972 - 25s - loss: 0.0735 - accuracy: 0.9744 - auc_1: 0.9956 - val_loss: 0.2622 - val_accuracy: 0.9285 - val_auc_1: 0.9694
# Epoch 31/50
# 5972/5972 - 25s - loss: 0.0963 - accuracy: 0.9665 - auc_1: 0.9932 - val_loss: 0.2796 - val_accuracy: 0.9252 - val_auc_1: 0.9672
# Epoch 32/50
# 5972/5972 - 25s - loss: 0.0704 - accuracy: 0.9751 - auc_1: 0.9958 - val_loss: 0.2913 - val_accuracy: 0.9258 - val_auc_1: 0.9686
# Epoch 33/50
# 5972/5972 - 25s - loss: 0.0677 - accuracy: 0.9767 - auc_1: 0.9960 - val_loss: 0.2752 - val_accuracy: 0.9279 - val_auc_1: 0.9711
# Epoch 34/50
# 5972/5972 - 25s - loss: 0.0539 - accuracy: 0.9816 - auc_1: 0.9974 - val_loss: 0.3269 - val_accuracy: 0.9309 - val_auc_1: 0.9652
# Epoch 35/50
# 5972/5972 - 25s - loss: 0.0507 - accuracy: 0.9823 - auc_1: 0.9975 - val_loss: 0.2997 - val_accuracy: 0.9335 - val_auc_1: 0.9697
# Epoch 36/50
# 5972/5972 - 25s - loss: 0.0476 - accuracy: 0.9836 - auc_1: 0.9978 - val_loss: 0.3151 - val_accuracy: 0.9349 - val_auc_1: 0.9663
# Epoch 37/50
# 5972/5972 - 25s - loss: 0.0646 - accuracy: 0.9751 - auc_1: 0.9968 - val_loss: 0.2696 - val_accuracy: 0.9309 - val_auc_1: 0.9706
# Epoch 38/50
# 5972/5972 - 25s - loss: 0.0719 - accuracy: 0.9742 - auc_1: 0.9958 - val_loss: 0.2608 - val_accuracy: 0.9344 - val_auc_1: 0.9713
# Epoch 39/50
# 5972/5972 - 24s - loss: 0.0624 - accuracy: 0.9777 - auc_1: 0.9968 - val_loss: 0.3052 - val_accuracy: 0.9285 - val_auc_1: 0.9663
# Epoch 40/50
# 5972/5972 - 24s - loss: 0.0492 - accuracy: 0.9833 - auc_1: 0.9977 - val_loss: 0.3185 - val_accuracy: 0.9322 - val_auc_1: 0.9665
# Epoch 41/50
# 5972/5972 - 24s - loss: 0.0446 - accuracy: 0.9849 - auc_1: 0.9980 - val_loss: 0.3309 - val_accuracy: 0.9319 - val_auc_1: 0.9644
# Epoch 42/50
# 5972/5972 - 24s - loss: 0.0450 - accuracy: 0.9851 - auc_1: 0.9980 - val_loss: 0.3264 - val_accuracy: 0.9354 - val_auc_1: 0.9653
# Epoch 43/50
# 5972/5972 - 24s - loss: 0.0439 - accuracy: 0.9854 - auc_1: 0.9980 - val_loss: 0.3429 - val_accuracy: 0.9365 - val_auc_1: 0.9653
# Epoch 44/50
# 5972/5972 - 24s - loss: 0.0419 - accuracy: 0.9859 - auc_1: 0.9980 - val_loss: 0.3407 - val_accuracy: 0.9357 - val_auc_1: 0.9670
# Epoch 45/50
# 5972/5972 - 24s - loss: 0.0502 - accuracy: 0.9817 - auc_1: 0.9975 - val_loss: 0.3419 - val_accuracy: 0.9277 - val_auc_1: 0.9615
# Epoch 46/50
# 5972/5972 - 24s - loss: 0.0577 - accuracy: 0.9789 - auc_1: 0.9972 - val_loss: 0.3010 - val_accuracy: 0.9357 - val_auc_1: 0.9683
# Epoch 47/50
# 5972/5972 - 24s - loss: 0.0710 - accuracy: 0.9744 - auc_1: 0.9957 - val_loss: 0.3055 - val_accuracy: 0.9287 - val_auc_1: 0.9654
# Epoch 48/50
# 5972/5972 - 24s - loss: 0.0569 - accuracy: 0.9806 - auc_1: 0.9970 - val_loss: 0.3158 - val_accuracy: 0.9338 - val_auc_1: 0.9655
# Epoch 49/50
# 5972/5972 - 24s - loss: 0.0448 - accuracy: 0.9834 - auc_1: 0.9983 - val_loss: 0.3214 - val_accuracy: 0.9357 - val_auc_1: 0.9684
# Epoch 50/50
# 5972/5972 - 24s - loss: 0.0515 - accuracy: 0.9819 - auc_1: 0.9977 - val_loss: 0.3192 - val_accuracy: 0.9319 - val_auc_1: 0.9673
# Training bag 1
# (14930, 1)
# (14930,)
# [1.58190727e-04 2.69111991e-03 7.70688057e-05 ... 3.09571594e-01
#  7.73668289e-05 9.90241744e-01]
# Loading test data 6051/6051: 100%|████████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# (6051, 1)
# (6051,)
# Saved to result_boosting_lstm_256_boost1.csv
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 3.46302986e-05
#  3.46302986e-05 3.45706940e-05]
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# Train on 5972 samples, validate on 3732 samples
# Epoch 1/50
# 5972/5972 - 27s - loss: 0.4522 - accuracy: 0.7753 - auc_3: 0.8343 - val_loss: 0.5951 - val_accuracy: 0.6340 - val_auc_3: 0.8536
# Epoch 2/50
# 5972/5972 - 25s - loss: 0.4159 - accuracy: 0.7917 - auc_3: 0.8608 - val_loss: 0.5603 - val_accuracy: 0.7610 - val_auc_3: 0.8837
# Epoch 3/50
# 5972/5972 - 25s - loss: 0.3940 - accuracy: 0.8051 - auc_3: 0.8775 - val_loss: 0.4905 - val_accuracy: 0.7704 - val_auc_3: 0.8944
# Epoch 4/50
# 5972/5972 - 25s - loss: 0.3775 - accuracy: 0.8197 - auc_3: 0.8882 - val_loss: 0.5599 - val_accuracy: 0.7468 - val_auc_3: 0.8846
# Epoch 5/50
# 5972/5972 - 25s - loss: 0.3561 - accuracy: 0.8304 - auc_3: 0.9009 - val_loss: 0.4895 - val_accuracy: 0.7792 - val_auc_3: 0.8915
# Epoch 6/50
# 5972/5972 - 25s - loss: 0.3503 - accuracy: 0.8381 - auc_3: 0.9045 - val_loss: 0.5277 - val_accuracy: 0.7079 - val_auc_3: 0.8868
# Epoch 7/50
# 5972/5972 - 25s - loss: 0.3319 - accuracy: 0.8508 - auc_3: 0.9142 - val_loss: 0.5982 - val_accuracy: 0.6830 - val_auc_3: 0.8662
# Epoch 8/50
# 5972/5972 - 25s - loss: 0.3232 - accuracy: 0.8567 - auc_3: 0.9179 - val_loss: 0.5133 - val_accuracy: 0.7417 - val_auc_3: 0.8940
# Epoch 9/50
# 5972/5972 - 25s - loss: 0.3147 - accuracy: 0.8615 - auc_3: 0.9225 - val_loss: 0.5365 - val_accuracy: 0.7350 - val_auc_3: 0.8926
# Epoch 10/50
# 5972/5972 - 25s - loss: 0.2939 - accuracy: 0.8751 - auc_3: 0.9303 - val_loss: 0.5905 - val_accuracy: 0.7251 - val_auc_3: 0.8568
# Epoch 11/50
# 5972/5972 - 25s - loss: 0.2797 - accuracy: 0.8814 - auc_3: 0.9373 - val_loss: 0.7139 - val_accuracy: 0.7275 - val_auc_3: 0.8700
# Epoch 12/50
# 5972/5972 - 25s - loss: 0.2635 - accuracy: 0.8917 - auc_3: 0.9430 - val_loss: 0.7045 - val_accuracy: 0.7315 - val_auc_3: 0.8555
# Epoch 13/50
# 5972/5972 - 24s - loss: 0.2552 - accuracy: 0.8890 - auc_3: 0.9468 - val_loss: 0.6447 - val_accuracy: 0.7371 - val_auc_3: 0.8509
# Epoch 14/50
# 5972/5972 - 24s - loss: 0.2361 - accuracy: 0.9024 - auc_3: 0.9535 - val_loss: 0.6535 - val_accuracy: 0.7457 - val_auc_3: 0.8651
# Epoch 15/50
# 5972/5972 - 24s - loss: 0.2285 - accuracy: 0.9082 - auc_3: 0.9566 - val_loss: 0.7645 - val_accuracy: 0.7366 - val_auc_3: 0.8595
# Epoch 16/50
# 5972/5972 - 24s - loss: 0.2204 - accuracy: 0.9104 - auc_3: 0.9586 - val_loss: 0.7409 - val_accuracy: 0.7382 - val_auc_3: 0.8398
# Epoch 17/50
# 5972/5972 - 24s - loss: 0.2110 - accuracy: 0.9174 - auc_3: 0.9618 - val_loss: 0.9483 - val_accuracy: 0.7329 - val_auc_3: 0.8195
# Epoch 18/50
# 5972/5972 - 24s - loss: 0.1983 - accuracy: 0.9223 - auc_3: 0.9667 - val_loss: 0.9332 - val_accuracy: 0.7406 - val_auc_3: 0.8101
# Epoch 19/50
# 5972/5972 - 24s - loss: 0.1859 - accuracy: 0.9313 - auc_3: 0.9694 - val_loss: 0.9677 - val_accuracy: 0.7229 - val_auc_3: 0.8177
# Epoch 20/50
# 5972/5972 - 24s - loss: 0.1876 - accuracy: 0.9287 - auc_3: 0.9686 - val_loss: 0.9871 - val_accuracy: 0.6902 - val_auc_3: 0.7867
# Epoch 21/50
# 5972/5972 - 24s - loss: 0.1788 - accuracy: 0.9318 - auc_3: 0.9723 - val_loss: 0.9542 - val_accuracy: 0.7393 - val_auc_3: 0.8134
# Epoch 22/50
# 5972/5972 - 24s - loss: 0.1718 - accuracy: 0.9347 - auc_3: 0.9730 - val_loss: 0.9634 - val_accuracy: 0.7495 - val_auc_3: 0.8152
# Epoch 23/50
# 5972/5972 - 24s - loss: 0.1594 - accuracy: 0.9402 - auc_3: 0.9759 - val_loss: 1.0246 - val_accuracy: 0.7492 - val_auc_3: 0.7970
# Epoch 24/50
# 5972/5972 - 24s - loss: 0.1509 - accuracy: 0.9451 - auc_3: 0.9783 - val_loss: 1.1092 - val_accuracy: 0.7462 - val_auc_3: 0.7797
# Epoch 25/50
# 5972/5972 - 25s - loss: 0.1551 - accuracy: 0.9459 - auc_3: 0.9773 - val_loss: 1.0770 - val_accuracy: 0.7575 - val_auc_3: 0.8275
# Epoch 26/50
# 5972/5972 - 25s - loss: 0.1438 - accuracy: 0.9491 - auc_3: 0.9803 - val_loss: 1.2588 - val_accuracy: 0.7173 - val_auc_3: 0.7603
# Epoch 27/50
# 5972/5972 - 24s - loss: 0.1387 - accuracy: 0.9498 - auc_3: 0.9812 - val_loss: 1.2300 - val_accuracy: 0.7385 - val_auc_3: 0.8247
# Epoch 28/50
# 5972/5972 - 24s - loss: 0.1353 - accuracy: 0.9513 - auc_3: 0.9823 - val_loss: 1.1689 - val_accuracy: 0.7433 - val_auc_3: 0.7998
# Epoch 29/50
# 5972/5972 - 25s - loss: 0.1346 - accuracy: 0.9496 - auc_3: 0.9821 - val_loss: 1.2170 - val_accuracy: 0.7564 - val_auc_3: 0.8354
# Epoch 30/50
# 5972/5972 - 24s - loss: 0.1387 - accuracy: 0.9504 - auc_3: 0.9811 - val_loss: 1.1993 - val_accuracy: 0.7363 - val_auc_3: 0.8060
# Epoch 31/50
# 5972/5972 - 24s - loss: 0.1330 - accuracy: 0.9534 - auc_3: 0.9816 - val_loss: 1.0492 - val_accuracy: 0.7605 - val_auc_3: 0.8241
# Epoch 32/50
# 5972/5972 - 24s - loss: 0.1245 - accuracy: 0.9585 - auc_3: 0.9836 - val_loss: 0.9275 - val_accuracy: 0.7671 - val_auc_3: 0.8369
# Epoch 33/50
# 5972/5972 - 24s - loss: 0.1205 - accuracy: 0.9578 - auc_3: 0.9852 - val_loss: 1.2009 - val_accuracy: 0.7529 - val_auc_3: 0.8065
# Epoch 34/50
# 5972/5972 - 25s - loss: 0.1165 - accuracy: 0.9578 - auc_3: 0.9859 - val_loss: 1.2596 - val_accuracy: 0.7645 - val_auc_3: 0.7916
# Epoch 35/50
# 5972/5972 - 24s - loss: 0.1179 - accuracy: 0.9570 - auc_3: 0.9858 - val_loss: 1.4067 - val_accuracy: 0.7479 - val_auc_3: 0.7739
# Epoch 36/50
# 5972/5972 - 24s - loss: 0.1594 - accuracy: 0.9404 - auc_3: 0.9768 - val_loss: 1.0502 - val_accuracy: 0.7401 - val_auc_3: 0.8190
# Epoch 37/50
# 5972/5972 - 25s - loss: 0.1599 - accuracy: 0.9416 - auc_3: 0.9761 - val_loss: 0.9099 - val_accuracy: 0.7575 - val_auc_3: 0.8145
# Epoch 38/50
# 5972/5972 - 24s - loss: 0.1343 - accuracy: 0.9514 - auc_3: 0.9820 - val_loss: 1.0941 - val_accuracy: 0.7661 - val_auc_3: 0.8119
# Epoch 39/50
# 5972/5972 - 24s - loss: 0.1178 - accuracy: 0.9571 - auc_3: 0.9857 - val_loss: 1.0727 - val_accuracy: 0.7551 - val_auc_3: 0.8500
# Epoch 40/50
# 5972/5972 - 24s - loss: 0.1102 - accuracy: 0.9596 - auc_3: 0.9868 - val_loss: 1.1528 - val_accuracy: 0.7599 - val_auc_3: 0.7734
# Epoch 41/50
# 5972/5972 - 24s - loss: 0.1072 - accuracy: 0.9620 - auc_3: 0.9873 - val_loss: 0.9607 - val_accuracy: 0.7655 - val_auc_3: 0.8069
# Epoch 42/50
# 5972/5972 - 24s - loss: 0.1061 - accuracy: 0.9625 - auc_3: 0.9876 - val_loss: 0.9366 - val_accuracy: 0.7503 - val_auc_3: 0.8144
# Epoch 43/50
# 5972/5972 - 24s - loss: 0.1145 - accuracy: 0.9598 - auc_3: 0.9862 - val_loss: 0.7322 - val_accuracy: 0.7822 - val_auc_3: 0.8610
# Epoch 44/50
# 5972/5972 - 24s - loss: 0.1127 - accuracy: 0.9617 - auc_3: 0.9864 - val_loss: 0.9197 - val_accuracy: 0.7822 - val_auc_3: 0.8396
# Epoch 45/50
# 5972/5972 - 24s - loss: 0.1102 - accuracy: 0.9612 - auc_3: 0.9873 - val_loss: 0.9664 - val_accuracy: 0.7232 - val_auc_3: 0.8127
# Epoch 46/50
# 5972/5972 - 24s - loss: 0.1109 - accuracy: 0.9630 - auc_3: 0.9863 - val_loss: 1.1245 - val_accuracy: 0.7505 - val_auc_3: 0.8446
# Epoch 47/50
# 5972/5972 - 24s - loss: 0.1156 - accuracy: 0.9586 - auc_3: 0.9852 - val_loss: 0.9380 - val_accuracy: 0.7693 - val_auc_3: 0.8370
# Epoch 48/50
# 5972/5972 - 24s - loss: 0.1086 - accuracy: 0.9630 - auc_3: 0.9868 - val_loss: 0.9441 - val_accuracy: 0.8076 - val_auc_3: 0.8573
# Epoch 49/50
# 5972/5972 - 24s - loss: 0.1116 - accuracy: 0.9613 - auc_3: 0.9871 - val_loss: 0.9120 - val_accuracy: 0.7763 - val_auc_3: 0.8526
# Epoch 50/50
# 5972/5972 - 24s - loss: 0.1143 - accuracy: 0.9596 - auc_3: 0.9865 - val_loss: 1.1497 - val_accuracy: 0.7706 - val_auc_3: 0.8110
# Training bag 2
# (14930, 2)
# (14930,)
# [7.93337822e-05 1.89185143e-03 5.60134649e-05 ... 2.19203681e-01
#  3.86834145e-05 4.95131850e-01]
# Loading test data 6051/6051: 100%|████████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# (6051, 2)
# (6051,)
# Saved to result_boosting_lstm_256_boost2.csv
# [0.99827237 0.99817683 0.99796812 ... 0.01340796 0.01340254 0.01338522]
# Train on 5972 samples, validate on 3732 samples
# Epoch 1/50
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# 5972/5972 - 27s - loss: 0.3809 - accuracy: 0.8225 - auc_5: 0.9006 - val_loss: 0.4263 - val_accuracy: 0.7771 - val_auc_5: 0.8694
# Epoch 2/50
# 5972/5972 - 24s - loss: 0.3224 - accuracy: 0.8538 - auc_5: 0.9310 - val_loss: 0.3995 - val_accuracy: 0.8178 - val_auc_5: 0.8975
# Epoch 3/50
# 5972/5972 - 24s - loss: 0.2829 - accuracy: 0.8739 - auc_5: 0.9468 - val_loss: 0.4168 - val_accuracy: 0.7862 - val_auc_5: 0.8802
# Epoch 4/50
# 5972/5972 - 24s - loss: 0.2756 - accuracy: 0.8803 - auc_5: 0.9495 - val_loss: 0.4213 - val_accuracy: 0.7596 - val_auc_5: 0.8725
# Epoch 5/50
# 5972/5972 - 24s - loss: 0.2569 - accuracy: 0.8888 - auc_5: 0.9552 - val_loss: 0.3759 - val_accuracy: 0.8344 - val_auc_5: 0.9105
# Epoch 6/50
# 5972/5972 - 24s - loss: 0.2492 - accuracy: 0.8905 - auc_5: 0.9573 - val_loss: 0.3293 - val_accuracy: 0.8526 - val_auc_5: 0.9309
# Epoch 7/50
# 5972/5972 - 24s - loss: 0.2366 - accuracy: 0.8982 - auc_5: 0.9611 - val_loss: 0.3969 - val_accuracy: 0.8084 - val_auc_5: 0.9018
# Epoch 8/50
# 5972/5972 - 24s - loss: 0.2231 - accuracy: 0.9030 - auc_5: 0.9646 - val_loss: 0.5125 - val_accuracy: 0.7709 - val_auc_5: 0.8394
# Epoch 9/50
# 5972/5972 - 24s - loss: 0.2281 - accuracy: 0.9037 - auc_5: 0.9634 - val_loss: 0.4582 - val_accuracy: 0.7897 - val_auc_5: 0.8733
# Epoch 10/50
# 5972/5972 - 24s - loss: 0.2108 - accuracy: 0.9126 - auc_5: 0.9683 - val_loss: 0.4167 - val_accuracy: 0.7998 - val_auc_5: 0.8853
# Epoch 11/50
# 5972/5972 - 25s - loss: 0.1915 - accuracy: 0.9220 - auc_5: 0.9732 - val_loss: 0.3551 - val_accuracy: 0.8682 - val_auc_5: 0.9319
# Epoch 12/50
# 5972/5972 - 25s - loss: 0.1852 - accuracy: 0.9238 - auc_5: 0.9745 - val_loss: 0.4506 - val_accuracy: 0.7915 - val_auc_5: 0.8869
# Epoch 13/50
# 5972/5972 - 25s - loss: 0.1784 - accuracy: 0.9253 - auc_5: 0.9747 - val_loss: 0.6097 - val_accuracy: 0.7765 - val_auc_5: 0.8548
# Epoch 14/50
# 5972/5972 - 25s - loss: 0.2013 - accuracy: 0.9181 - auc_5: 0.9713 - val_loss: 0.4028 - val_accuracy: 0.8221 - val_auc_5: 0.9133
# Epoch 15/50
# 5972/5972 - 25s - loss: 0.2205 - accuracy: 0.9079 - auc_5: 0.9656 - val_loss: 0.4590 - val_accuracy: 0.8194 - val_auc_5: 0.8810
# Epoch 16/50
# 5972/5972 - 25s - loss: 0.2291 - accuracy: 0.9014 - auc_5: 0.9641 - val_loss: 0.3450 - val_accuracy: 0.8569 - val_auc_5: 0.9267
# Epoch 17/50
# 5972/5972 - 25s - loss: 0.1937 - accuracy: 0.9176 - auc_5: 0.9732 - val_loss: 0.4283 - val_accuracy: 0.7915 - val_auc_5: 0.8981
# Epoch 18/50
# 5972/5972 - 24s - loss: 0.1843 - accuracy: 0.9211 - auc_5: 0.9742 - val_loss: 0.5105 - val_accuracy: 0.8063 - val_auc_5: 0.8808
# Epoch 19/50
# 5972/5972 - 25s - loss: 0.1720 - accuracy: 0.9295 - auc_5: 0.9769 - val_loss: 0.5813 - val_accuracy: 0.7872 - val_auc_5: 0.8709
# Epoch 20/50
# 5972/5972 - 25s - loss: 0.1611 - accuracy: 0.9354 - auc_5: 0.9790 - val_loss: 0.5263 - val_accuracy: 0.7840 - val_auc_5: 0.8766
# Epoch 21/50
# 5972/5972 - 25s - loss: 0.1562 - accuracy: 0.9379 - auc_5: 0.9801 - val_loss: 0.6202 - val_accuracy: 0.7939 - val_auc_5: 0.8730
# Epoch 22/50
# 5972/5972 - 25s - loss: 0.1530 - accuracy: 0.9355 - auc_5: 0.9808 - val_loss: 0.6124 - val_accuracy: 0.7950 - val_auc_5: 0.8758
# Epoch 23/50
# 5972/5972 - 25s - loss: 0.1503 - accuracy: 0.9402 - auc_5: 0.9810 - val_loss: 0.5334 - val_accuracy: 0.7725 - val_auc_5: 0.8844
# Epoch 24/50
# 5972/5972 - 25s - loss: 0.1575 - accuracy: 0.9390 - auc_5: 0.9803 - val_loss: 0.6052 - val_accuracy: 0.7926 - val_auc_5: 0.8731
# Epoch 25/50
# 5972/5972 - 25s - loss: 0.1529 - accuracy: 0.9385 - auc_5: 0.9816 - val_loss: 0.9065 - val_accuracy: 0.7891 - val_auc_5: 0.8001
# Epoch 26/50
# 5972/5972 - 25s - loss: 0.1584 - accuracy: 0.9345 - auc_5: 0.9802 - val_loss: 0.7923 - val_accuracy: 0.7832 - val_auc_5: 0.8199
# Epoch 27/50
# 5972/5972 - 25s - loss: 0.1504 - accuracy: 0.9396 - auc_5: 0.9819 - val_loss: 0.6095 - val_accuracy: 0.7939 - val_auc_5: 0.8772
# Epoch 28/50
# 5972/5972 - 25s - loss: 0.1511 - accuracy: 0.9375 - auc_5: 0.9821 - val_loss: 0.7867 - val_accuracy: 0.7996 - val_auc_5: 0.8174
# Epoch 29/50
# 5972/5972 - 24s - loss: 0.1390 - accuracy: 0.9451 - auc_5: 0.9841 - val_loss: 0.8422 - val_accuracy: 0.7773 - val_auc_5: 0.8182
# Epoch 30/50
# 5972/5972 - 24s - loss: 0.1482 - accuracy: 0.9421 - auc_5: 0.9820 - val_loss: 0.7146 - val_accuracy: 0.7956 - val_auc_5: 0.8637
# Epoch 31/50
# 5972/5972 - 25s - loss: 0.1360 - accuracy: 0.9486 - auc_5: 0.9843 - val_loss: 0.8069 - val_accuracy: 0.7889 - val_auc_5: 0.8290
# Epoch 32/50
# 5972/5972 - 24s - loss: 0.1414 - accuracy: 0.9431 - auc_5: 0.9837 - val_loss: 0.4582 - val_accuracy: 0.8376 - val_auc_5: 0.9135
# Epoch 33/50
# 5972/5972 - 24s - loss: 0.1365 - accuracy: 0.9454 - auc_5: 0.9843 - val_loss: 0.6994 - val_accuracy: 0.7819 - val_auc_5: 0.8733
# Epoch 34/50
# 5972/5972 - 25s - loss: 0.1266 - accuracy: 0.9494 - auc_5: 0.9863 - val_loss: 0.8098 - val_accuracy: 0.7843 - val_auc_5: 0.8759
# Epoch 35/50
# 5972/5972 - 25s - loss: 0.1304 - accuracy: 0.9464 - auc_5: 0.9857 - val_loss: 0.6545 - val_accuracy: 0.7838 - val_auc_5: 0.8888
# Epoch 36/50
# 5972/5972 - 24s - loss: 0.1406 - accuracy: 0.9419 - auc_5: 0.9840 - val_loss: 0.8330 - val_accuracy: 0.7902 - val_auc_5: 0.8482
# Epoch 37/50
# 5972/5972 - 24s - loss: 0.1328 - accuracy: 0.9464 - auc_5: 0.9852 - val_loss: 0.7522 - val_accuracy: 0.7996 - val_auc_5: 0.8679
# Epoch 38/50
# 5972/5972 - 24s - loss: 0.1358 - accuracy: 0.9454 - auc_5: 0.9845 - val_loss: 0.9623 - val_accuracy: 0.7856 - val_auc_5: 0.8220
# Epoch 39/50
# 5972/5972 - 25s - loss: 0.1350 - accuracy: 0.9446 - auc_5: 0.9851 - val_loss: 0.8527 - val_accuracy: 0.7805 - val_auc_5: 0.8261
# Epoch 40/50
# 5972/5972 - 25s - loss: 0.1359 - accuracy: 0.9473 - auc_5: 0.9846 - val_loss: 0.9616 - val_accuracy: 0.7765 - val_auc_5: 0.8158
# Epoch 41/50
# 5972/5972 - 24s - loss: 0.1333 - accuracy: 0.9473 - auc_5: 0.9850 - val_loss: 1.0181 - val_accuracy: 0.7937 - val_auc_5: 0.8156
# Epoch 42/50
# 5972/5972 - 24s - loss: 0.1268 - accuracy: 0.9493 - auc_5: 0.9863 - val_loss: 0.9001 - val_accuracy: 0.7816 - val_auc_5: 0.8344
# Epoch 43/50
# 5972/5972 - 25s - loss: 0.1253 - accuracy: 0.9504 - auc_5: 0.9867 - val_loss: 0.9393 - val_accuracy: 0.7982 - val_auc_5: 0.8393
# Epoch 44/50
# 5972/5972 - 24s - loss: 0.1210 - accuracy: 0.9529 - auc_5: 0.9874 - val_loss: 0.9931 - val_accuracy: 0.7872 - val_auc_5: 0.8323
# Epoch 45/50
# 5972/5972 - 24s - loss: 0.1298 - accuracy: 0.9506 - auc_5: 0.9858 - val_loss: 1.0777 - val_accuracy: 0.7824 - val_auc_5: 0.8153
# Epoch 46/50
# 5972/5972 - 24s - loss: 0.1154 - accuracy: 0.9548 - auc_5: 0.9885 - val_loss: 1.1782 - val_accuracy: 0.7846 - val_auc_5: 0.8165
# Epoch 47/50
# 5972/5972 - 24s - loss: 0.1154 - accuracy: 0.9550 - auc_5: 0.9885 - val_loss: 1.1892 - val_accuracy: 0.7851 - val_auc_5: 0.8095
# Epoch 48/50
# 5972/5972 - 25s - loss: 0.1151 - accuracy: 0.9543 - auc_5: 0.9883 - val_loss: 0.9366 - val_accuracy: 0.7680 - val_auc_5: 0.8440
# Epoch 49/50
# 5972/5972 - 24s - loss: 0.1375 - accuracy: 0.9488 - auc_5: 0.9845 - val_loss: 0.6251 - val_accuracy: 0.7650 - val_auc_5: 0.8669
# Epoch 50/50
# 5972/5972 - 24s - loss: 0.1245 - accuracy: 0.9506 - auc_5: 0.9872 - val_loss: 0.8841 - val_accuracy: 0.7840 - val_auc_5: 0.8369
# Training bag 3
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-3-34db7e02d4d5> in <module>
#      25             model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
#      26             if validate_bag == 0:
# ---> 27                 predictions = model.predict(train_data_x)
#      28             else:
#      29                 predictions = np.concatenate((predictions,model.predict(train_data_x)),axis=1)
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     907         max_queue_size=max_queue_size,
#     908         workers=workers,
# --> 909         use_multiprocessing=use_multiprocessing)
#     910
#     911   def reset_metrics(self):
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     460     return self._model_iteration(
#     461         model, ModeKeys.PREDICT, x=x, batch_size=batch_size, verbose=verbose,
# --> 462         steps=steps, callbacks=callbacks, **kwargs)
#     463
#     464
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, **kwargs)
#     442               mode=mode,
#     443               training_context=training_context,
# --> 444               total_epochs=1)
#     445           cbks.make_logs(model, epoch_logs, result, mode)
#     446
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     492       # In this case we have not created variables on the first call. So we can
#     493       # run the first trace but we should fail if variables are created.
# --> 494       results = self._stateful_fn(*args, **kwds)
#     495       if self._created_variables:
#     496         raise ValueError("Creating variables on a non-first call to a function"
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# c:\users\hao\appdata\local\programs\python\python37\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError:  [_Derived_]  Failed to call ThenRnnForward with model config: [rnn_mode, rnn_input_mode, rnn_direction_mode]: 2, 0, 0 , [num_layers, input_size, num_units, dir_count, max_seq_length, batch_size, cell_num_units]: [1, 102, 256, 1, 1000, 32, 256]
# 	 [[{{node CudnnRNN}}]]
# 	 [[sequential_6/bidirectional_6/backward_lstm_6/StatefulPartitionedCall]] [Op:__inference_distributed_function_228241]
#
# Function call stack:
# distributed_function -> distributed_function -> distributed_function

# %% [markdown]
# ## Restore Weights

# %%
checkpoint_dir = './checkpoints/' + model_name
model = create_model()

import numpy as np
from data import Data

test_data = Data(data_type='test')
print("Test data: x:"+ str(test_data.x.shape)+ ' y:'+str(test_data.y.shape))

for bag in range(num_of_bags):
    checkpoint_dir = './checkpoints/' + model_name+ '_bag'+ str(bag)
    model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
    if bag == 0:
        predictions = model.predict(test_data.x)
    else:
        predictions = np.concatenate((predictions,model.predict(test_data.x)),axis=1)
print(predictions.shape)

avg_predictions = np.mean(predictions, axis=1)
print(avg_predictions.shape)
# Out:
# Loading test data 6051/6051: 100%|████████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# Test data: x:(6051, 1000, 102) y:(6051, 1)
# (6051, 3)
# (6051,)

# %% [markdown]
# ## Save Prediction to CSV

# %%
import csv

output_file = 'result_' + model_name + '.csv'
with open(output_file, 'wt', newline='', encoding='utf-8') as output_file:
    csv_writer = csv.writer(output_file)
    csv_writer.writerow(('Id', 'Predicted'))
    for id, predict in enumerate(avg_predictions):
        csv_writer.writerow((id, predict))
print('Saved to '+'result_' + model_name + '.csv')
# Out:
# Saved to result_boosting_lstm_256.csv
