# %% [markdown]
# # CS5242

# %% [markdown]
# ## Load Data

# %%
from data import Data
import numpy as np

full_train = Data(data_type='train')

# idx = np.random.permutation(len(full_train.x))
# full_train_x,full_train_y = full_train.x[idx], full_train.y[idx]
full_train_x,full_train_y = full_train.x, full_train.y


del full_train

val_data_x, train_data_x = full_train_x[:full_train_x.shape[0]//5,:], full_train_x[full_train_x.shape[0]//5:,:]
val_data_y,train_data_y = full_train_y[:full_train_y.shape[0]//5,:], full_train_y[full_train_y.shape[0]//5:,:]

print("Train data: x:"+ str(train_data_x.shape)+ ' y:'+str(train_data_y.shape))
print("Validation data: x:"+ str(val_data_x.shape)+ ' y:'+str(val_data_y.shape))
# Out:
# Loading train data 18662/18662: 100%|█████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# Train data: x:(14930, 1000, 102) y:(14930, 1)
# Validation data: x:(3732, 1000, 102) y:(3732, 1)

# %% [markdown]
# ## Model

# %%
import tensorflow as tf
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], True)

model_name = 'boosting_lstm_pooling_2'

def create_model(show_summary = False):
    model = tf.keras.Sequential([
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True),input_shape=(1000,102)),
        tf.keras.layers.GlobalMaxPooling1D(),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(rate=0.2),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(1e-4,0.95,0.99),
                  metrics=['accuracy',tf.keras.metrics.AUC()])
    
    if show_summary:
        model.summary()
    
    return model
    
num_of_bags = 10
epochs_per_bag = 250
start_from_bag = 0

# %% [markdown]
# ## Training with Boosting

# %%
import os
import matplotlib.pyplot as plt
import csv
import math
from data import Data

# %matplotlib inline
    
training_loss = np.ones(train_data_x.shape[0])

for bag in range(num_of_bags):
    # skip training
    if bag < start_from_bag:
        print("skiping bag "+str(bag))
        continue
    print("Training bag "+str(bag))

    # Put data into bags
    model = create_model(False)
    train_size = train_data_x.shape[0]//10*4
    if bag != 0 :
        # Check prediction for training data
        for validate_bag in range(bag):
            checkpoint_dir = './checkpoints/' + model_name+ '_bag'+ str(validate_bag)
            model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
            if validate_bag == 0:
                predictions = model.predict(train_data_x)
            else:
                predictions = np.concatenate((predictions,model.predict(train_data_x)),axis=1)
        print(predictions.shape)

        avg_predictions = np.mean(predictions, axis=1)
        print(avg_predictions.shape)
        
        # Select training data poorly predicted 
        training_loss = avg_predictions-np.reshape(train_data_y,(train_data_y.shape[0]))
        training_loss = np.absolute(training_loss)
        print(training_loss)
        
        # Save Predictions for test data
        test_data = Data(data_type='test')
        for validate_bag in range(bag):
            checkpoint_dir = './checkpoints/' + model_name+ '_bag'+ str(validate_bag)
            model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
            if validate_bag == 0:
                predictions = model.predict(test_data.x)
            else:
                predictions = np.concatenate((predictions,model.predict(test_data.x)),axis=1)
        print(predictions.shape)

        avg_predictions = np.mean(predictions, axis=1)
        print(avg_predictions.shape)
        
        output_file = 'result_' + model_name +'_boost'+ str(bag) +'.csv'
        with open(output_file, 'wt', newline='', encoding='utf-8') as output_file:
            csv_writer = csv.writer(output_file)
            csv_writer.writerow(('Id', 'Predicted'))
            for id, predict in enumerate(avg_predictions):
                csv_writer.writerow((id, predict))
        print('Saved to '+'result_' + model_name +'_boost'+ str(bag) +'.csv')
        # Free memory space for test data
        del test_data
        
        
    
    idx = (-training_loss).argsort()[:train_size]
    print(training_loss[idx])
    bag_x,bag_y = train_data_x[idx], train_data_y[idx]
        
    del model
        
    ## TODO define different models if possible
    model = create_model(bag==0)
    # Directory where the checkpoints will be saved
    checkpoint_dir = './checkpoints/' + model_name+ '_bag'+ str(bag)
    # Name of the checkpoint files
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

    checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_prefix,
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=True)

    early_stopping_callback = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        min_delta=0, 
        patience=60, 
        mode='auto', 
        restore_best_weights=True)
        
        
        
    history = model.fit(x=bag_x,y=bag_y, validation_data=(val_data_x,val_data_y), epochs=epochs_per_bag,batch_size=32,
                    callbacks=[checkpoint_callback,early_stopping_callback], verbose=2,shuffle=True)
    
    print()
    
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()
    
    del model,history,bag_x,bag_y
# Out:
# Training bag 0
# [1. 1. 1. ... 1. 1. 1.]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 1000, 256)         236544
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 302,593
# Trainable params: 302,593
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5972 samples, validate on 3732 samples
# Epoch 1/250
# 5972/5972 - 22s - loss: 0.4646 - accuracy: 0.7905 - auc_1: 0.8741 - val_loss: 0.3693 - val_accuracy: 0.8545 - val_auc_1: 0.9346
# Epoch 2/250
# 5972/5972 - 17s - loss: 0.3118 - accuracy: 0.8679 - auc_1: 0.9478 - val_loss: 0.2766 - val_accuracy: 0.8942 - val_auc_1: 0.9573
# Epoch 3/250
# 5972/5972 - 17s - loss: 0.2518 - accuracy: 0.8970 - auc_1: 0.9642 - val_loss: 0.2377 - val_accuracy: 0.9003 - val_auc_1: 0.9671
# Epoch 4/250
# 5972/5972 - 18s - loss: 0.2177 - accuracy: 0.9126 - auc_1: 0.9730 - val_loss: 0.2169 - val_accuracy: 0.9129 - val_auc_1: 0.9722
# Epoch 5/250
# 5972/5972 - 18s - loss: 0.1946 - accuracy: 0.9270 - auc_1: 0.9780 - val_loss: 0.1962 - val_accuracy: 0.9239 - val_auc_1: 0.9763
# Epoch 6/250
# 5972/5972 - 18s - loss: 0.1772 - accuracy: 0.9320 - auc_1: 0.9816 - val_loss: 0.1852 - val_accuracy: 0.9266 - val_auc_1: 0.9784
# Epoch 7/250
# 5972/5972 - 18s - loss: 0.1605 - accuracy: 0.9406 - auc_1: 0.9843 - val_loss: 0.1781 - val_accuracy: 0.9314 - val_auc_1: 0.9803
# Epoch 8/250
# 5972/5972 - 18s - loss: 0.1504 - accuracy: 0.9444 - auc_1: 0.9861 - val_loss: 0.1689 - val_accuracy: 0.9330 - val_auc_1: 0.9820
# Epoch 9/250
# 5972/5972 - 18s - loss: 0.1431 - accuracy: 0.9449 - auc_1: 0.9870 - val_loss: 0.1617 - val_accuracy: 0.9330 - val_auc_1: 0.9830
# Epoch 10/250
# 5972/5972 - 18s - loss: 0.1311 - accuracy: 0.9498 - auc_1: 0.9890 - val_loss: 0.1611 - val_accuracy: 0.9352 - val_auc_1: 0.9839
# Epoch 11/250
# 5972/5972 - 18s - loss: 0.1241 - accuracy: 0.9578 - auc_1: 0.9901 - val_loss: 0.1537 - val_accuracy: 0.9381 - val_auc_1: 0.9845
# Epoch 12/250
# 5972/5972 - 18s - loss: 0.1205 - accuracy: 0.9586 - auc_1: 0.9903 - val_loss: 0.1681 - val_accuracy: 0.9376 - val_auc_1: 0.9843
# Epoch 13/250
# 5972/5972 - 18s - loss: 0.1128 - accuracy: 0.9581 - auc_1: 0.9915 - val_loss: 0.1519 - val_accuracy: 0.9394 - val_auc_1: 0.9852
# Epoch 14/250
# 5972/5972 - 18s - loss: 0.1034 - accuracy: 0.9658 - auc_1: 0.9926 - val_loss: 0.1489 - val_accuracy: 0.9416 - val_auc_1: 0.9859
# Epoch 15/250
# 5972/5972 - 18s - loss: 0.1021 - accuracy: 0.9642 - auc_1: 0.9927 - val_loss: 0.1527 - val_accuracy: 0.9408 - val_auc_1: 0.9854
# Epoch 16/250
# 5972/5972 - 18s - loss: 0.1001 - accuracy: 0.9658 - auc_1: 0.9928 - val_loss: 0.1459 - val_accuracy: 0.9421 - val_auc_1: 0.9862
# Epoch 17/250
# 5972/5972 - 18s - loss: 0.0932 - accuracy: 0.9678 - auc_1: 0.9937 - val_loss: 0.1447 - val_accuracy: 0.9411 - val_auc_1: 0.9867
# Epoch 18/250
# 5972/5972 - 18s - loss: 0.0869 - accuracy: 0.9697 - auc_1: 0.9944 - val_loss: 0.1436 - val_accuracy: 0.9432 - val_auc_1: 0.9863
# Epoch 19/250
# 5972/5972 - 18s - loss: 0.0846 - accuracy: 0.9739 - auc_1: 0.9946 - val_loss: 0.1508 - val_accuracy: 0.9437 - val_auc_1: 0.9858
# Epoch 20/250
# 5972/5972 - 18s - loss: 0.0779 - accuracy: 0.9725 - auc_1: 0.9956 - val_loss: 0.1448 - val_accuracy: 0.9437 - val_auc_1: 0.9869
# Epoch 21/250
# 5972/5972 - 18s - loss: 0.0758 - accuracy: 0.9745 - auc_1: 0.9956 - val_loss: 0.1458 - val_accuracy: 0.9437 - val_auc_1: 0.9864
# Epoch 22/250
# 5972/5972 - 18s - loss: 0.0727 - accuracy: 0.9791 - auc_1: 0.9957 - val_loss: 0.1482 - val_accuracy: 0.9467 - val_auc_1: 0.9868
# Epoch 23/250
# 5972/5972 - 18s - loss: 0.0696 - accuracy: 0.9784 - auc_1: 0.9963 - val_loss: 0.1474 - val_accuracy: 0.9440 - val_auc_1: 0.9866
# Epoch 24/250
# 5972/5972 - 18s - loss: 0.0666 - accuracy: 0.9776 - auc_1: 0.9964 - val_loss: 0.1672 - val_accuracy: 0.9424 - val_auc_1: 0.9858
# Epoch 25/250
# 5972/5972 - 18s - loss: 0.0686 - accuracy: 0.9776 - auc_1: 0.9959 - val_loss: 0.1480 - val_accuracy: 0.9448 - val_auc_1: 0.9862
# Epoch 26/250
# 5972/5972 - 18s - loss: 0.0652 - accuracy: 0.9801 - auc_1: 0.9964 - val_loss: 0.1635 - val_accuracy: 0.9402 - val_auc_1: 0.9861
# Epoch 27/250
# 5972/5972 - 18s - loss: 0.0679 - accuracy: 0.9794 - auc_1: 0.9961 - val_loss: 0.1491 - val_accuracy: 0.9424 - val_auc_1: 0.9867
# Epoch 28/250
# 5972/5972 - 18s - loss: 0.0583 - accuracy: 0.9824 - auc_1: 0.9970 - val_loss: 0.1527 - val_accuracy: 0.9472 - val_auc_1: 0.9863
# Epoch 29/250
# 5972/5972 - 18s - loss: 0.0610 - accuracy: 0.9824 - auc_1: 0.9964 - val_loss: 0.1453 - val_accuracy: 0.9469 - val_auc_1: 0.9858
# Epoch 30/250
# 5972/5972 - 18s - loss: 0.0548 - accuracy: 0.9851 - auc_1: 0.9974 - val_loss: 0.1531 - val_accuracy: 0.9480 - val_auc_1: 0.9861
# Epoch 31/250
# 5972/5972 - 18s - loss: 0.0618 - accuracy: 0.9812 - auc_1: 0.9966 - val_loss: 0.1653 - val_accuracy: 0.9475 - val_auc_1: 0.9861
# Epoch 32/250
# 5972/5972 - 18s - loss: 0.0544 - accuracy: 0.9824 - auc_1: 0.9971 - val_loss: 0.1472 - val_accuracy: 0.9504 - val_auc_1: 0.9865
# Epoch 33/250
# 5972/5972 - 18s - loss: 0.0537 - accuracy: 0.9844 - auc_1: 0.9972 - val_loss: 0.1514 - val_accuracy: 0.9437 - val_auc_1: 0.9845
# Epoch 34/250
# 5972/5972 - 18s - loss: 0.0535 - accuracy: 0.9834 - auc_1: 0.9971 - val_loss: 0.1534 - val_accuracy: 0.9445 - val_auc_1: 0.9846
# Epoch 35/250
# 5972/5972 - 18s - loss: 0.0517 - accuracy: 0.9858 - auc_1: 0.9973 - val_loss: 0.1614 - val_accuracy: 0.9496 - val_auc_1: 0.9863
# Epoch 36/250
# 5972/5972 - 18s - loss: 0.0544 - accuracy: 0.9836 - auc_1: 0.9971 - val_loss: 0.1613 - val_accuracy: 0.9429 - val_auc_1: 0.9849
# Epoch 37/250
# 5972/5972 - 18s - loss: 0.0482 - accuracy: 0.9848 - auc_1: 0.9976 - val_loss: 0.1652 - val_accuracy: 0.9486 - val_auc_1: 0.9860
# Epoch 38/250
# 5972/5972 - 18s - loss: 0.0478 - accuracy: 0.9848 - auc_1: 0.9977 - val_loss: 0.1539 - val_accuracy: 0.9472 - val_auc_1: 0.9854
# Epoch 39/250
# 5972/5972 - 18s - loss: 0.0474 - accuracy: 0.9868 - auc_1: 0.9975 - val_loss: 0.1749 - val_accuracy: 0.9472 - val_auc_1: 0.9851
# Epoch 40/250
# 5972/5972 - 18s - loss: 0.0459 - accuracy: 0.9854 - auc_1: 0.9978 - val_loss: 0.1583 - val_accuracy: 0.9472 - val_auc_1: 0.9848
# Epoch 41/250
# 5972/5972 - 18s - loss: 0.0463 - accuracy: 0.9859 - auc_1: 0.9976 - val_loss: 0.1592 - val_accuracy: 0.9499 - val_auc_1: 0.9855
# Epoch 42/250
# 5972/5972 - 18s - loss: 0.0453 - accuracy: 0.9863 - auc_1: 0.9980 - val_loss: 0.1565 - val_accuracy: 0.9464 - val_auc_1: 0.9839
# Epoch 43/250
# 5972/5972 - 18s - loss: 0.0441 - accuracy: 0.9869 - auc_1: 0.9980 - val_loss: 0.1626 - val_accuracy: 0.9475 - val_auc_1: 0.9844
# Epoch 44/250
# 5972/5972 - 18s - loss: 0.0464 - accuracy: 0.9853 - auc_1: 0.9976 - val_loss: 0.1739 - val_accuracy: 0.9472 - val_auc_1: 0.9841
# Epoch 45/250
# 5972/5972 - 18s - loss: 0.0448 - accuracy: 0.9871 - auc_1: 0.9976 - val_loss: 0.1563 - val_accuracy: 0.9475 - val_auc_1: 0.9852
# Epoch 46/250
# 5972/5972 - 18s - loss: 0.0461 - accuracy: 0.9868 - auc_1: 0.9979 - val_loss: 0.1751 - val_accuracy: 0.9494 - val_auc_1: 0.9861
# Epoch 47/250
# 5972/5972 - 18s - loss: 0.0446 - accuracy: 0.9866 - auc_1: 0.9981 - val_loss: 0.1556 - val_accuracy: 0.9491 - val_auc_1: 0.9850
# Epoch 48/250
# 5972/5972 - 18s - loss: 0.0417 - accuracy: 0.9874 - auc_1: 0.9980 - val_loss: 0.1605 - val_accuracy: 0.9445 - val_auc_1: 0.9839
# Epoch 49/250
# 5972/5972 - 18s - loss: 0.0424 - accuracy: 0.9876 - auc_1: 0.9978 - val_loss: 0.1690 - val_accuracy: 0.9480 - val_auc_1: 0.9837
# Epoch 50/250
# 5972/5972 - 18s - loss: 0.0414 - accuracy: 0.9866 - auc_1: 0.9980 - val_loss: 0.1625 - val_accuracy: 0.9459 - val_auc_1: 0.9839
# Epoch 51/250
# 5972/5972 - 18s - loss: 0.0424 - accuracy: 0.9856 - auc_1: 0.9984 - val_loss: 0.1628 - val_accuracy: 0.9499 - val_auc_1: 0.9842
# Epoch 52/250
# 5972/5972 - 18s - loss: 0.0390 - accuracy: 0.9878 - auc_1: 0.9984 - val_loss: 0.1683 - val_accuracy: 0.9488 - val_auc_1: 0.9834
# Epoch 53/250
# 5972/5972 - 18s - loss: 0.0399 - accuracy: 0.9881 - auc_1: 0.9982 - val_loss: 0.1716 - val_accuracy: 0.9477 - val_auc_1: 0.9847
# Epoch 54/250
# 5972/5972 - 18s - loss: 0.0402 - accuracy: 0.9871 - auc_1: 0.9983 - val_loss: 0.1605 - val_accuracy: 0.9496 - val_auc_1: 0.9845
# Epoch 55/250
# 5972/5972 - 18s - loss: 0.0432 - accuracy: 0.9863 - auc_1: 0.9980 - val_loss: 0.2164 - val_accuracy: 0.9432 - val_auc_1: 0.9820
# Epoch 56/250
# 5972/5972 - 18s - loss: 0.0391 - accuracy: 0.9881 - auc_1: 0.9984 - val_loss: 0.1711 - val_accuracy: 0.9451 - val_auc_1: 0.9828
# Epoch 57/250
# 5972/5972 - 18s - loss: 0.0380 - accuracy: 0.9879 - auc_1: 0.9984 - val_loss: 0.1652 - val_accuracy: 0.9510 - val_auc_1: 0.9841
# Epoch 58/250
# 5972/5972 - 18s - loss: 0.0393 - accuracy: 0.9888 - auc_1: 0.9984 - val_loss: 0.1693 - val_accuracy: 0.9507 - val_auc_1: 0.9840
# Epoch 59/250
# 5972/5972 - 18s - loss: 0.0404 - accuracy: 0.9873 - auc_1: 0.9983 - val_loss: 0.1768 - val_accuracy: 0.9467 - val_auc_1: 0.9847
# Epoch 60/250
# 5972/5972 - 18s - loss: 0.0378 - accuracy: 0.9874 - auc_1: 0.9984 - val_loss: 0.1671 - val_accuracy: 0.9523 - val_auc_1: 0.9832
# Epoch 61/250
# 5972/5972 - 18s - loss: 0.0378 - accuracy: 0.9873 - auc_1: 0.9984 - val_loss: 0.1716 - val_accuracy: 0.9510 - val_auc_1: 0.9831
# Epoch 62/250
# 5972/5972 - 18s - loss: 0.0389 - accuracy: 0.9878 - auc_1: 0.9983 - val_loss: 0.1694 - val_accuracy: 0.9472 - val_auc_1: 0.9826
# Epoch 63/250
# 5972/5972 - 18s - loss: 0.0369 - accuracy: 0.9888 - auc_1: 0.9983 - val_loss: 0.1795 - val_accuracy: 0.9443 - val_auc_1: 0.9828
# Epoch 64/250
# 5972/5972 - 18s - loss: 0.0369 - accuracy: 0.9886 - auc_1: 0.9986 - val_loss: 0.1669 - val_accuracy: 0.9483 - val_auc_1: 0.9830
# Epoch 65/250
# 5972/5972 - 18s - loss: 0.0354 - accuracy: 0.9886 - auc_1: 0.9987 - val_loss: 0.1942 - val_accuracy: 0.9480 - val_auc_1: 0.9835
# Epoch 66/250
# 5972/5972 - 18s - loss: 0.0357 - accuracy: 0.9886 - auc_1: 0.9986 - val_loss: 0.1747 - val_accuracy: 0.9480 - val_auc_1: 0.9834
# Epoch 67/250
# 5972/5972 - 18s - loss: 0.0364 - accuracy: 0.9884 - auc_1: 0.9985 - val_loss: 0.1697 - val_accuracy: 0.9472 - val_auc_1: 0.9835
# Epoch 68/250
# 5972/5972 - 18s - loss: 0.0371 - accuracy: 0.9884 - auc_1: 0.9984 - val_loss: 0.1893 - val_accuracy: 0.9424 - val_auc_1: 0.9821
# Epoch 69/250
# 5972/5972 - 18s - loss: 0.0367 - accuracy: 0.9883 - auc_1: 0.9985 - val_loss: 0.1771 - val_accuracy: 0.9507 - val_auc_1: 0.9822
# Epoch 70/250
# 5972/5972 - 18s - loss: 0.0362 - accuracy: 0.9881 - auc_1: 0.9986 - val_loss: 0.1794 - val_accuracy: 0.9534 - val_auc_1: 0.9837
# Epoch 71/250
# 5972/5972 - 18s - loss: 0.0343 - accuracy: 0.9883 - auc_1: 0.9988 - val_loss: 0.2300 - val_accuracy: 0.9333 - val_auc_1: 0.9774
# Epoch 72/250
# 5972/5972 - 18s - loss: 0.0370 - accuracy: 0.9886 - auc_1: 0.9986 - val_loss: 0.1731 - val_accuracy: 0.9510 - val_auc_1: 0.9837
# Epoch 73/250
# 5972/5972 - 18s - loss: 0.0353 - accuracy: 0.9884 - auc_1: 0.9985 - val_loss: 0.1794 - val_accuracy: 0.9453 - val_auc_1: 0.9827
# Epoch 74/250
# 5972/5972 - 18s - loss: 0.0353 - accuracy: 0.9883 - auc_1: 0.9985 - val_loss: 0.1811 - val_accuracy: 0.9523 - val_auc_1: 0.9814
# Epoch 75/250
# 5972/5972 - 18s - loss: 0.0346 - accuracy: 0.9884 - auc_1: 0.9987 - val_loss: 0.1814 - val_accuracy: 0.9461 - val_auc_1: 0.9829
# Epoch 76/250
# 5972/5972 - 18s - loss: 0.0397 - accuracy: 0.9871 - auc_1: 0.9984 - val_loss: 0.1757 - val_accuracy: 0.9499 - val_auc_1: 0.9830
# Epoch 77/250
# 5972/5972 - 18s - loss: 0.0347 - accuracy: 0.9886 - auc_1: 0.9987 - val_loss: 0.1702 - val_accuracy: 0.9496 - val_auc_1: 0.9834
# Epoch 78/250
# 5972/5972 - 18s - loss: 0.0366 - accuracy: 0.9884 - auc_1: 0.9984 - val_loss: 0.1827 - val_accuracy: 0.9453 - val_auc_1: 0.9834
# Training bag 1
# (14930, 1)
# (14930,)
# [0.00068545 0.00136006 0.01093405 ... 0.06521353 0.02887827 0.31755871]
# Loading test data 6051/6051: 100%|████████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# (6051, 1)
# (6051,)
# Saved to result_boosting_lstm_pooling_2_boost1.csv
# [0.9985463  0.99802628 0.99779043 ... 0.00718251 0.00715488 0.00715029]
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# Train on 5972 samples, validate on 3732 samples
# Epoch 1/250
# 5972/5972 - 20s - loss: 0.6363 - accuracy: 0.6266 - auc_3: 0.6787 - val_loss: 0.5075 - val_accuracy: 0.8499 - val_auc_3: 0.8995
# Epoch 2/250
# 5972/5972 - 18s - loss: 0.5757 - accuracy: 0.7045 - auc_3: 0.7722 - val_loss: 0.4611 - val_accuracy: 0.8872 - val_auc_3: 0.9432
# Epoch 3/250
# 5972/5972 - 18s - loss: 0.5133 - accuracy: 0.7647 - auc_3: 0.8392 - val_loss: 0.3725 - val_accuracy: 0.9118 - val_auc_3: 0.9564
# Epoch 4/250
# 5972/5972 - 18s - loss: 0.4641 - accuracy: 0.8123 - auc_3: 0.8736 - val_loss: 0.3156 - val_accuracy: 0.9236 - val_auc_3: 0.9623
# Epoch 5/250
# 5972/5972 - 18s - loss: 0.4208 - accuracy: 0.8290 - auc_3: 0.8958 - val_loss: 0.2964 - val_accuracy: 0.9325 - val_auc_3: 0.9669
# Epoch 6/250
# 5972/5972 - 18s - loss: 0.3844 - accuracy: 0.8483 - auc_3: 0.9113 - val_loss: 0.2538 - val_accuracy: 0.9376 - val_auc_3: 0.9704
# Epoch 7/250
# 5972/5972 - 18s - loss: 0.3551 - accuracy: 0.8657 - auc_3: 0.9228 - val_loss: 0.2351 - val_accuracy: 0.9397 - val_auc_3: 0.9730
# Epoch 8/250
# 5972/5972 - 18s - loss: 0.3331 - accuracy: 0.8679 - auc_3: 0.9312 - val_loss: 0.2190 - val_accuracy: 0.9421 - val_auc_3: 0.9752
# Epoch 9/250
# 5972/5972 - 18s - loss: 0.3136 - accuracy: 0.8768 - auc_3: 0.9367 - val_loss: 0.2104 - val_accuracy: 0.9435 - val_auc_3: 0.9756
# Epoch 10/250
# 5972/5972 - 18s - loss: 0.3014 - accuracy: 0.8831 - auc_3: 0.9421 - val_loss: 0.1934 - val_accuracy: 0.9445 - val_auc_3: 0.9774
# Epoch 11/250
# 5972/5972 - 18s - loss: 0.2874 - accuracy: 0.8905 - auc_3: 0.9452 - val_loss: 0.1756 - val_accuracy: 0.9451 - val_auc_3: 0.9792
# Epoch 12/250
# 5972/5972 - 18s - loss: 0.2696 - accuracy: 0.8979 - auc_3: 0.9521 - val_loss: 0.1853 - val_accuracy: 0.9405 - val_auc_3: 0.9783
# Epoch 13/250
# 5972/5972 - 18s - loss: 0.2573 - accuracy: 0.9027 - auc_3: 0.9567 - val_loss: 0.1702 - val_accuracy: 0.9496 - val_auc_3: 0.9809
# Epoch 14/250
# 5972/5972 - 18s - loss: 0.2467 - accuracy: 0.9114 - auc_3: 0.9589 - val_loss: 0.1789 - val_accuracy: 0.9314 - val_auc_3: 0.9803
# Epoch 15/250
# 5972/5972 - 18s - loss: 0.2324 - accuracy: 0.9154 - auc_3: 0.9624 - val_loss: 0.1613 - val_accuracy: 0.9459 - val_auc_3: 0.9807
# Epoch 16/250
# 5972/5972 - 18s - loss: 0.2261 - accuracy: 0.9210 - auc_3: 0.9632 - val_loss: 0.1557 - val_accuracy: 0.9523 - val_auc_3: 0.9818
# Epoch 17/250
# 5972/5972 - 18s - loss: 0.2147 - accuracy: 0.9240 - auc_3: 0.9676 - val_loss: 0.1635 - val_accuracy: 0.9344 - val_auc_3: 0.9827
# Epoch 18/250
# 5972/5972 - 18s - loss: 0.2050 - accuracy: 0.9275 - auc_3: 0.9693 - val_loss: 0.1552 - val_accuracy: 0.9477 - val_auc_3: 0.9834
# Epoch 19/250
# 5972/5972 - 18s - loss: 0.1992 - accuracy: 0.9324 - auc_3: 0.9709 - val_loss: 0.1482 - val_accuracy: 0.9531 - val_auc_3: 0.9851
# Epoch 20/250
# 5972/5972 - 18s - loss: 0.1942 - accuracy: 0.9345 - auc_3: 0.9719 - val_loss: 0.1463 - val_accuracy: 0.9515 - val_auc_3: 0.9847
# Epoch 21/250
# 5972/5972 - 18s - loss: 0.1855 - accuracy: 0.9399 - auc_3: 0.9739 - val_loss: 0.1465 - val_accuracy: 0.9512 - val_auc_3: 0.9849
# Epoch 22/250
# 5972/5972 - 18s - loss: 0.1799 - accuracy: 0.9396 - auc_3: 0.9749 - val_loss: 0.1380 - val_accuracy: 0.9574 - val_auc_3: 0.9864
# Epoch 23/250
# 5972/5972 - 18s - loss: 0.1741 - accuracy: 0.9427 - auc_3: 0.9772 - val_loss: 0.1659 - val_accuracy: 0.9311 - val_auc_3: 0.9834
# Epoch 24/250
# 5972/5972 - 18s - loss: 0.1676 - accuracy: 0.9424 - auc_3: 0.9789 - val_loss: 0.1347 - val_accuracy: 0.9571 - val_auc_3: 0.9850
# Epoch 25/250
# 5972/5972 - 18s - loss: 0.1653 - accuracy: 0.9461 - auc_3: 0.9782 - val_loss: 0.1395 - val_accuracy: 0.9563 - val_auc_3: 0.9853
# Epoch 26/250
# 5972/5972 - 18s - loss: 0.1557 - accuracy: 0.9491 - auc_3: 0.9811 - val_loss: 0.1359 - val_accuracy: 0.9585 - val_auc_3: 0.9858
# Epoch 27/250
# 5972/5972 - 18s - loss: 0.1562 - accuracy: 0.9513 - auc_3: 0.9795 - val_loss: 0.1367 - val_accuracy: 0.9577 - val_auc_3: 0.9854
# Epoch 28/250
# 5972/5972 - 18s - loss: 0.1481 - accuracy: 0.9538 - auc_3: 0.9827 - val_loss: 0.1873 - val_accuracy: 0.9285 - val_auc_3: 0.9830
# Epoch 29/250
# 5972/5972 - 18s - loss: 0.1443 - accuracy: 0.9533 - auc_3: 0.9836 - val_loss: 0.1461 - val_accuracy: 0.9547 - val_auc_3: 0.9848
# Epoch 30/250
# 5972/5972 - 18s - loss: 0.1424 - accuracy: 0.9551 - auc_3: 0.9836 - val_loss: 0.1335 - val_accuracy: 0.9590 - val_auc_3: 0.9861
# Epoch 31/250
# 5972/5972 - 18s - loss: 0.1385 - accuracy: 0.9536 - auc_3: 0.9845 - val_loss: 0.1488 - val_accuracy: 0.9539 - val_auc_3: 0.9840
# Epoch 32/250
# 5972/5972 - 18s - loss: 0.1379 - accuracy: 0.9560 - auc_3: 0.9842 - val_loss: 0.1482 - val_accuracy: 0.9381 - val_auc_3: 0.9851
# Epoch 33/250
# 5972/5972 - 18s - loss: 0.1362 - accuracy: 0.9560 - auc_3: 0.9841 - val_loss: 0.1510 - val_accuracy: 0.9563 - val_auc_3: 0.9847
# Epoch 34/250
# 5972/5972 - 18s - loss: 0.1282 - accuracy: 0.9590 - auc_3: 0.9861 - val_loss: 0.1597 - val_accuracy: 0.9330 - val_auc_3: 0.9838
# Epoch 35/250
# 5972/5972 - 18s - loss: 0.1314 - accuracy: 0.9563 - auc_3: 0.9862 - val_loss: 0.1464 - val_accuracy: 0.9579 - val_auc_3: 0.9852
# Epoch 36/250
# 5972/5972 - 18s - loss: 0.1260 - accuracy: 0.9593 - auc_3: 0.9862 - val_loss: 0.1614 - val_accuracy: 0.9295 - val_auc_3: 0.9833
# Epoch 37/250
# 5972/5972 - 18s - loss: 0.1211 - accuracy: 0.9615 - auc_3: 0.9872 - val_loss: 0.1466 - val_accuracy: 0.9579 - val_auc_3: 0.9853
# Epoch 38/250
# 5972/5972 - 18s - loss: 0.1190 - accuracy: 0.9620 - auc_3: 0.9880 - val_loss: 0.1429 - val_accuracy: 0.9561 - val_auc_3: 0.9856
# Epoch 39/250
# 5972/5972 - 18s - loss: 0.1190 - accuracy: 0.9610 - auc_3: 0.9881 - val_loss: 0.1710 - val_accuracy: 0.9271 - val_auc_3: 0.9805
# Epoch 40/250
# 5972/5972 - 18s - loss: 0.1225 - accuracy: 0.9596 - auc_3: 0.9872 - val_loss: 0.2077 - val_accuracy: 0.9041 - val_auc_3: 0.9759
# Epoch 41/250
# 5972/5972 - 18s - loss: 0.1224 - accuracy: 0.9601 - auc_3: 0.9875 - val_loss: 0.1560 - val_accuracy: 0.9327 - val_auc_3: 0.9843
# Epoch 42/250
# 5972/5972 - 18s - loss: 0.1177 - accuracy: 0.9603 - auc_3: 0.9880 - val_loss: 0.1696 - val_accuracy: 0.9268 - val_auc_3: 0.9826
# Epoch 43/250
# 5972/5972 - 18s - loss: 0.1098 - accuracy: 0.9635 - auc_3: 0.9897 - val_loss: 0.1764 - val_accuracy: 0.9124 - val_auc_3: 0.9819
# Epoch 44/250
# 5972/5972 - 18s - loss: 0.1106 - accuracy: 0.9642 - auc_3: 0.9892 - val_loss: 0.1831 - val_accuracy: 0.9116 - val_auc_3: 0.9825
# Epoch 45/250
# 5972/5972 - 18s - loss: 0.1061 - accuracy: 0.9655 - auc_3: 0.9905 - val_loss: 0.1557 - val_accuracy: 0.9373 - val_auc_3: 0.9844
# Epoch 46/250
# 5972/5972 - 18s - loss: 0.1080 - accuracy: 0.9635 - auc_3: 0.9902 - val_loss: 0.1897 - val_accuracy: 0.9116 - val_auc_3: 0.9822
# Epoch 47/250
# 5972/5972 - 18s - loss: 0.1046 - accuracy: 0.9657 - auc_3: 0.9907 - val_loss: 0.2044 - val_accuracy: 0.9049 - val_auc_3: 0.9829
# Epoch 48/250
# 5972/5972 - 18s - loss: 0.1148 - accuracy: 0.9628 - auc_3: 0.9882 - val_loss: 0.1723 - val_accuracy: 0.9236 - val_auc_3: 0.9827
# Epoch 49/250
# 5972/5972 - 18s - loss: 0.1038 - accuracy: 0.9653 - auc_3: 0.9903 - val_loss: 0.1996 - val_accuracy: 0.9084 - val_auc_3: 0.9777
# Epoch 50/250
# 5972/5972 - 18s - loss: 0.1031 - accuracy: 0.9658 - auc_3: 0.9908 - val_loss: 0.1839 - val_accuracy: 0.9108 - val_auc_3: 0.9842
# Epoch 51/250
# 5972/5972 - 18s - loss: 0.1104 - accuracy: 0.9635 - auc_3: 0.9893 - val_loss: 0.1844 - val_accuracy: 0.9116 - val_auc_3: 0.9814
# Epoch 52/250
# 5972/5972 - 18s - loss: 0.1056 - accuracy: 0.9668 - auc_3: 0.9902 - val_loss: 0.2209 - val_accuracy: 0.9068 - val_auc_3: 0.9809
# Epoch 53/250
# 5972/5972 - 18s - loss: 0.0998 - accuracy: 0.9690 - auc_3: 0.9912 - val_loss: 0.1896 - val_accuracy: 0.9102 - val_auc_3: 0.9794
# Epoch 54/250
# 5972/5972 - 18s - loss: 0.1025 - accuracy: 0.9675 - auc_3: 0.9908 - val_loss: 0.1783 - val_accuracy: 0.9159 - val_auc_3: 0.9840
# Epoch 55/250
# 5972/5972 - 18s - loss: 0.1013 - accuracy: 0.9658 - auc_3: 0.9912 - val_loss: 0.1926 - val_accuracy: 0.9092 - val_auc_3: 0.9840
# Epoch 56/250
# 5972/5972 - 18s - loss: 0.0988 - accuracy: 0.9645 - auc_3: 0.9917 - val_loss: 0.1906 - val_accuracy: 0.9089 - val_auc_3: 0.9843
# Epoch 57/250
# 5972/5972 - 18s - loss: 0.1009 - accuracy: 0.9665 - auc_3: 0.9912 - val_loss: 0.1773 - val_accuracy: 0.9151 - val_auc_3: 0.9827
# Epoch 58/250
# 5972/5972 - 18s - loss: 0.0974 - accuracy: 0.9689 - auc_3: 0.9915 - val_loss: 0.1935 - val_accuracy: 0.9121 - val_auc_3: 0.9816
# Epoch 59/250
# 5972/5972 - 18s - loss: 0.0990 - accuracy: 0.9665 - auc_3: 0.9911 - val_loss: 0.1940 - val_accuracy: 0.9137 - val_auc_3: 0.9817
# Epoch 60/250
# 5972/5972 - 18s - loss: 0.0938 - accuracy: 0.9675 - auc_3: 0.9925 - val_loss: 0.2503 - val_accuracy: 0.9035 - val_auc_3: 0.9792
# Epoch 61/250
# 5972/5972 - 18s - loss: 0.0976 - accuracy: 0.9677 - auc_3: 0.9917 - val_loss: 0.2305 - val_accuracy: 0.8904 - val_auc_3: 0.9742
# Epoch 62/250
# 5972/5972 - 18s - loss: 0.0948 - accuracy: 0.9680 - auc_3: 0.9920 - val_loss: 0.2255 - val_accuracy: 0.9073 - val_auc_3: 0.9827
# Epoch 63/250
# 5972/5972 - 18s - loss: 0.0958 - accuracy: 0.9673 - auc_3: 0.9920 - val_loss: 0.2371 - val_accuracy: 0.9038 - val_auc_3: 0.9803
# Epoch 64/250
# 5972/5972 - 18s - loss: 0.0912 - accuracy: 0.9678 - auc_3: 0.9929 - val_loss: 0.2030 - val_accuracy: 0.9084 - val_auc_3: 0.9797
# Epoch 65/250
# 5972/5972 - 18s - loss: 0.0940 - accuracy: 0.9680 - auc_3: 0.9922 - val_loss: 0.2295 - val_accuracy: 0.9070 - val_auc_3: 0.9810
# Epoch 66/250
# 5972/5972 - 18s - loss: 0.0919 - accuracy: 0.9695 - auc_3: 0.9925 - val_loss: 0.2082 - val_accuracy: 0.9113 - val_auc_3: 0.9797
# Epoch 67/250
# 5972/5972 - 18s - loss: 0.0929 - accuracy: 0.9697 - auc_3: 0.9922 - val_loss: 0.2062 - val_accuracy: 0.9118 - val_auc_3: 0.9788
# Epoch 68/250
# 5972/5972 - 18s - loss: 0.0909 - accuracy: 0.9695 - auc_3: 0.9926 - val_loss: 0.2405 - val_accuracy: 0.9049 - val_auc_3: 0.9750
# Epoch 69/250
# 5972/5972 - 18s - loss: 0.0950 - accuracy: 0.9675 - auc_3: 0.9918 - val_loss: 0.2328 - val_accuracy: 0.9084 - val_auc_3: 0.9775
# Epoch 70/250
# 5972/5972 - 18s - loss: 0.0942 - accuracy: 0.9697 - auc_3: 0.9917 - val_loss: 0.1919 - val_accuracy: 0.9124 - val_auc_3: 0.9812
# Epoch 71/250
# 5972/5972 - 18s - loss: 0.0886 - accuracy: 0.9697 - auc_3: 0.9930 - val_loss: 0.2288 - val_accuracy: 0.9070 - val_auc_3: 0.9793
# Epoch 72/250
# 5972/5972 - 18s - loss: 0.0950 - accuracy: 0.9685 - auc_3: 0.9923 - val_loss: 0.2165 - val_accuracy: 0.8992 - val_auc_3: 0.9752
# Epoch 73/250
# 5972/5972 - 18s - loss: 0.0915 - accuracy: 0.9702 - auc_3: 0.9927 - val_loss: 0.1970 - val_accuracy: 0.9126 - val_auc_3: 0.9818
# Epoch 74/250
# 5972/5972 - 18s - loss: 0.0899 - accuracy: 0.9704 - auc_3: 0.9925 - val_loss: 0.2335 - val_accuracy: 0.9057 - val_auc_3: 0.9788
# Epoch 75/250
# 5972/5972 - 18s - loss: 0.0884 - accuracy: 0.9695 - auc_3: 0.9930 - val_loss: 0.2349 - val_accuracy: 0.9025 - val_auc_3: 0.9735
# Epoch 76/250
# 5972/5972 - 18s - loss: 0.0899 - accuracy: 0.9702 - auc_3: 0.9925 - val_loss: 0.2236 - val_accuracy: 0.9092 - val_auc_3: 0.9812
# Epoch 77/250
# 5972/5972 - 18s - loss: 0.0894 - accuracy: 0.9699 - auc_3: 0.9926 - val_loss: 0.2779 - val_accuracy: 0.9022 - val_auc_3: 0.9814
# Epoch 78/250
# 5972/5972 - 18s - loss: 0.0878 - accuracy: 0.9707 - auc_3: 0.9930 - val_loss: 0.2542 - val_accuracy: 0.9051 - val_auc_3: 0.9810
# Epoch 79/250
# 5972/5972 - 18s - loss: 0.0878 - accuracy: 0.9687 - auc_3: 0.9936 - val_loss: 0.2329 - val_accuracy: 0.9094 - val_auc_3: 0.9797
# Epoch 80/250
# 5972/5972 - 18s - loss: 0.0883 - accuracy: 0.9705 - auc_3: 0.9926 - val_loss: 0.2511 - val_accuracy: 0.9057 - val_auc_3: 0.9781
# Epoch 81/250
# 5972/5972 - 18s - loss: 0.0877 - accuracy: 0.9709 - auc_3: 0.9929 - val_loss: 0.2365 - val_accuracy: 0.9078 - val_auc_3: 0.9795
# Epoch 82/250
# 5972/5972 - 18s - loss: 0.0895 - accuracy: 0.9685 - auc_3: 0.9927 - val_loss: 0.2417 - val_accuracy: 0.9065 - val_auc_3: 0.9807
# Epoch 83/250
# 5972/5972 - 18s - loss: 0.0878 - accuracy: 0.9699 - auc_3: 0.9930 - val_loss: 0.2176 - val_accuracy: 0.9070 - val_auc_3: 0.9784
# Epoch 84/250
# 5972/5972 - 18s - loss: 0.0904 - accuracy: 0.9700 - auc_3: 0.9926 - val_loss: 0.2195 - val_accuracy: 0.9121 - val_auc_3: 0.9772
# Epoch 85/250
# 5972/5972 - 18s - loss: 0.0871 - accuracy: 0.9707 - auc_3: 0.9929 - val_loss: 0.2058 - val_accuracy: 0.9070 - val_auc_3: 0.9781
# Epoch 86/250
# 5972/5972 - 18s - loss: 0.0874 - accuracy: 0.9702 - auc_3: 0.9934 - val_loss: 0.2345 - val_accuracy: 0.9113 - val_auc_3: 0.9781
# Epoch 87/250
# 5972/5972 - 18s - loss: 0.0860 - accuracy: 0.9704 - auc_3: 0.9932 - val_loss: 0.2708 - val_accuracy: 0.9030 - val_auc_3: 0.9713
# Epoch 88/250
# 5972/5972 - 18s - loss: 0.0877 - accuracy: 0.9704 - auc_3: 0.9931 - val_loss: 0.3186 - val_accuracy: 0.8984 - val_auc_3: 0.9782
# Epoch 89/250
# 5972/5972 - 18s - loss: 0.0876 - accuracy: 0.9702 - auc_3: 0.9930 - val_loss: 0.2440 - val_accuracy: 0.9025 - val_auc_3: 0.9742
# Epoch 90/250
# 5972/5972 - 18s - loss: 0.0880 - accuracy: 0.9689 - auc_3: 0.9928 - val_loss: 0.2432 - val_accuracy: 0.9081 - val_auc_3: 0.9816
# Training bag 2
# (14930, 2)
# (14930,)
# [0.00051969 0.08463353 0.00767392 ... 0.07039171 0.01981854 0.1613394 ]
# Loading test data 6051/6051: 100%|████████████████████████████████████████████████████████████████ [ time left: 00:00 ]
# (6051, 2)
# (6051,)
# Saved to result_boosting_lstm_pooling_2_boost2.csv
# [0.99268879 0.98288244 0.97187763 ... 0.02138019 0.02137992 0.02136709]
# Train on 5972 samples, validate on 3732 samples
# Epoch 1/250
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# 5972/5972 - 22s - loss: 0.4974 - accuracy: 0.7430 - auc_5: 0.7821 - val_loss: 0.6145 - val_accuracy: 0.5587 - val_auc_5: 0.8070
# Epoch 2/250
# 5972/5972 - 18s - loss: 0.4257 - accuracy: 0.7830 - auc_5: 0.8500 - val_loss: 0.5730 - val_accuracy: 0.6206 - val_auc_5: 0.8594
# Epoch 3/250
# 5972/5972 - 18s - loss: 0.4021 - accuracy: 0.7991 - auc_5: 0.8687 - val_loss: 0.5341 - val_accuracy: 0.7170 - val_auc_5: 0.9012
# Epoch 4/250
# 5972/5972 - 18s - loss: 0.3816 - accuracy: 0.8116 - auc_5: 0.8835 - val_loss: 0.4890 - val_accuracy: 0.7658 - val_auc_5: 0.9182
# Epoch 5/250

# %% [markdown]
# ## Restore Weights

# %%
checkpoint_dir = './checkpoints/' + model_name
model = create_model()

import numpy as np
from data import Data

test_data = Data(data_type='test')
print("Test data: x:"+ str(test_data.x.shape)+ ' y:'+str(test_data.y.shape))

for bag in range(num_of_bags):
    checkpoint_dir = './checkpoints/' + model_name+ '_bag'+ str(bag)
    model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
    if bag == 0:
        predictions = model.predict(test_data.x)
    else:
        predictions = np.concatenate((predictions,model.predict(test_data.x)),axis=1)
print(predictions.shape)

avg_predictions = np.mean(predictions, axis=1)
print(avg_predictions.shape)

# %% [markdown]
# ## Save Prediction to CSV

# %%
import csv

output_file = 'result_' + model_name + '.csv'
with open(output_file, 'wt', newline='', encoding='utf-8') as output_file:
    csv_writer = csv.writer(output_file)
    csv_writer.writerow(('Id', 'Predicted'))
    for id, predict in enumerate(avg_predictions):
        csv_writer.writerow((id, predict))
print('Saved to '+'result_' + model_name + '.csv')
